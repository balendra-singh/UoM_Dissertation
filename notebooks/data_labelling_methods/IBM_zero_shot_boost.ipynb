# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

drive_path = "/content/drive/MyDrive/Dissertation/ibm-zero-shot/"
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Dissertation/ibm-zero-shot/
# Out:
# /content/drive/MyDrive/Dissertation/ibm-zero-shot

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Dissertation/ibm-zero-shot

# %%
import pandas as pd

# %%
# !pip install transformers==4.20 datasets==2.2.2 tqdm==4.64.1

# %%
# !python run_self_training_experiment.py --experiment_name user_Story_labelling --dataset_name user_stories --base_model sileod/deberta-v3-large-tasksource-nli
# Out:
# Streaming output truncated to the last 5000 lines.
#     3,
#     2,
#     8,
#     17,
#     18,
#     2,
#     2,
#     2,
#     2,
#     3,
#     11,
#     3,
#     42,
#     3,
#     7,
#     12,
#     7,
#     4,
#     100,
#     13,
#     100,
#     8,
#     1,
#     20,
#     2,
#     2,
#     4,
#     5,
#     3,
#     4,
#     14,
#     2,
#     6,
#     4,
#     2,
#     1,
#     3,
#     10,
#     3,
#     10,
#     4,
#     2,
#     7,
#     6,
#     28,
#     3,
#     6,
#     6,
#     7,
#     3,
#     5,
#     4,
#     2,
#     20,
#     2,
#     2,
#     2,
#     2,
#     2,
#     6,
#     7,
#     2,
#     13,
#     9,
#     2,
#     3,
#     4,
#     2,
#     3,
#     4,
#     2,
#     2,
#     2,
#     2,
#     4,
#     1,
#     2,
#     1,
#     13,
#     3,
#     5,
#     11,
#     37,
#     2,
#     49,
#     12,
#     40,
#     10,
#     4,
#     1,
#     2,
#     2,
#     1,
#     5,
#     3,
#     2,
#     3,
#     2,
#     2,
#     12,
#     3,
#     3,
# ...
